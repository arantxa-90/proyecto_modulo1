# %%
#Haz una lista llamada colores donde almacenemos los primeros 6 colores que te vengan a la mente.
#Haz una lista llamada buses de las líneas de autobuses que pasan por tu casa.
#Apunta la previsión de temperaturas máximas para todos los días de esta semana en temperaturas.

colores = ['negro', 'blanco', 'rosa', 'amarillo', 'azul', 'lila']
buses = [1, 2, 3]
temperaturas = [7, 7, 6, 6, 7, 11, 10]

# %%
#Convierte tu(s) nombre(s) a una lista nombres de caracteres.
#Convierte tu(s) apellido(s) a una lista apellidos de caracteres.

nombre = 'Arantxa'
apellido = 'Barea'

# %%
lista_nombre = list(nombre)
lista_apellido = list(apellido)

# %%
print(lista_nombre)
print(lista_apellido)
# Out:
# ['A', 'r', 'a', 'n', 't', 'x', 'a']
# ['B', 'a', 'r', 'e', 'a']

# %%
#¿Cuántos búses pasan por tu casa?

len(buses)
# Out:
# 3

# %%
#¿Cuántos caracteres hay en tu apellido(s) (inluyendo los espacios)?

len(lista_apellido)
# Out:
# 5

# %%
#¿Cuáles son las temperaturas máximas (t_max) y mínimas (t_min) para esta semana?

t_max = max(temperaturas)
t_min = min(temperaturas)

# %%
print(t_max)
print(t_min)
# Out:
# 11
# 6

# %%
#Hay una 'e' en tu nombre?

'e' in lista_nombre
# Out:
# False

# %%
#Tienes el color 'rosa' en la lista de colores?

'rosa' in colores
# Out:
# True

# %%
#¿Tiene una 'x' tu nombre? (Usa not in)
'x' not in lista_nombre
# Out:
# False

# %%
#Copia el contenido de temperaturas a temperaturas2, y temperaturas3.

temperaturas2 = temperaturas.copy()
temperaturas3 = temperaturas.copy()

# %%
#Vacía el contenido de la variable temperaturas2
temperaturas2.clear()

# %%
#Imprime el contenido de temperaturas y temperaturas2.

print(temperaturas)
print(temperaturas2)
print(temperaturas3)
# Out:
# [7, 7, 6, 6, 7, 11, 10]
# []
# [11, 10, 7, 7, 7, 6, 6]

# %% [markdown]
# Copia el contenido de nombres a nombres2.
#
# Copia el contenido de apellidos a apellidos2.

# %%
nombre2 = lista_nombre.copy()
apellido2 = lista_apellido.copy()

# %%
nombre2 + apellido2
# Out:
# ['A', 'r', 'a', 'n', 't', 'x', 'a', 'B', 'a', 'r', 'e', 'a']

# %%
#Ordena la variable temperaturas3 de mayor a menor.

temperaturas3.sort(reverse=True)

# %%
print(temperaturas3)
# Out:
# [11, 10, 7, 7, 7, 6, 6]

# %%
#Ordena los caracteres de tu nombre y tu apellido en las listas nombres2 y apellidos2. Imprime el resultado y investiga: ¿qué orden ha cogido? ¿Cómo trata las mayúsculas?

nombre2.sort()

# %%
nombre2
# Out:
# ['A', 'a', 'a', 'n', 'r', 't', 'x']

# %%
apellido2.sort()

# %%
apellido2
# Out:
# ['B', 'a', 'a', 'e', 'r']

# %%
#Cuántas 'a' tiene tu nombre? ¿Y cuántas 'o'?

print(f'Tiene', nombre2.count('a'), 'a y tiene', nombre2.count('o'), 'o')
# Out:
# Tiene 2 a y tiene 0 o

# %%
#¿Cuántas veces esta semana llega la temperatura a la t_max? ¿Y cuántas a la t_min?

print(f'La temperatura maxima llega', temperaturas.count(t_max), 'días y la temperatura minima llega', temperaturas.count(t_min), 'dias')
# Out:
# La temperatura maxima llega 1 días y la temperatura minima llega 2 dias

# %%
lista_dias = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']
temperaturas_diciembre = [10, 10, 13, 14, 12, 15, 
                        12, 11, 13, 17, 18, 15, 
                        15, 17, 17, 13, 13, 11,
                        12, 10, 12, 14, 12, 12,
                        11, 12, 16, 16, 14, 17, 18]

# %%
temperaturas_diciembre
# Out:
# [10,
#  10,
#  13,
#  14,
#  12,
#  15,
#  12,
#  11,
#  13,
#  17,
#  18,
#  15,
#  15,
#  17,
#  17,
#  13,
#  13,
#  11,
#  12,
#  10,
#  12,
#  14,
#  12,
#  12,
#  11,
#  12,
#  16,
#  16,
#  14,
#  17,
#  18]

# %%
#¿Cuál es el penúltimo día de la semana?

lista_dias[-2]
# Out:
# 'saturday'

# %%
#¿Cuál es el último elemento de la lista de temperaturas de diciembre?
temperaturas_diciembre[-1]
# Out:
# 18

# %%
#¿Está 'friday' en la lista de días en inglés? Si está, ¿dónde?

'friday' in lista_dias
# Out:
# True

# %%
print(lista_dias.index('friday'))
# Out:
# 4

# %%
#¿Cuál era la temperatura máxima en diciembre?

print(max(temperaturas_diciembre))
# Out:
# 18

# %%
#Encuentra el índice de 'miércoles' en dias_es.

print(lista_dias.index('wednesday'))
# Out:
# 2

# %%
print(f'La temperatura máxima esta semana será', max(temperaturas), 'ºC, que ocurrirá en', temperaturas.count(t_max), 'día(s). El día más frío tendrá una temperatura máxima de', min(temperaturas),  'ºC, que ocurrirá en', temperaturas.count(t_min), 'día(s).')
# Out:
# La temperatura máxima esta semana será 11 ºC, que ocurrirá en 1 día(s). El día más frío tendrá una temperatura máxima de 6 ºC, que ocurrirá en 2 día(s).
